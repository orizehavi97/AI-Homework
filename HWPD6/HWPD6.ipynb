# %% [markdown]
# ## Homework PANDAS 6
#
# import numpy, pandas ,display and pyplot

# %%
import numpy as np
import pandas as pd
from IPython.display import display

# %%
df = pd.read_csv("sport_athletes.csv")
display(df)
# Out:
#         Country       Sport Type          Athlete Name  Height(cm)  \
# 0           USA       Basketball        Michael Jordan         198
# 1           USA       Basketball          LeBron James         206
# 2           USA       Basketball           Kobe Bryant         198
# 3           USA       Basketball          Kevin Durant         208
# 4           USA       Basketball      Shaquille O'Neal         216
# 5        Brazil           Soccer                  Pelé         174
# 6        Brazil           Soccer                 Marta         163
# 7      Portugal           Soccer     Cristiano Ronaldo         187
# 8     Argentina           Soccer          Lionel Messi         170
# 9        France           Soccer       Zinedine Zidane         185
# 10          USA           Soccer         Megan Rapinoe         168
# 11          USA         Swimming        Michael Phelps         193
# 12          USA         Swimming         Katie Ledecky         180
# ...

# %% [markdown]
# **EX 1**
# PANDAS exercise

# %%
display(df.groupby('Sport Type')[['Weight(kg)']].min().rename(columns={'Weight(kg)':'max_weight'}))
display(df.groupby('Sport Type')[['Height(cm)']].max().rename(columns={'Height(cm)':'max_height'}))
display(df.groupby('Sport Type')[['Wins']].max().rename(columns={'Wins':'max_wins'}))
# Out:
#                  max_weight
# Sport Type
# Basketball               96
# Cycling                  68
# Gymnastics               45
# Soccer                   57
# Swimming                 58
# Tennis                   70
# Track and Field          57
#                  max_height
# Sport Type
# Basketball              216
# Cycling                 186
# Gymnastics              160
# Soccer                  187
# Swimming                200
# Tennis                  188
# Track and Field         195
#                  max_wins
# Sport Type
# Basketball              3
# Cycling                 5
# Gymnastics              5
# Soccer                  3
# Swimming                5
# Tennis                  4
# Track and Field         6

# %% [markdown]
# **EX 2**
# PANDAS exercise

# %%
display(df.groupby('Sport Type')['Height(cm)'].nlargest(2))
# Out:
# Sport Type
# Basketball       4     216
#                  3     208
# Cycling          28    186
#                  27    184
# Gymnastics       33    160
#                  34    157
# Soccer           7     187
#                  9     185
# Swimming         15    200
#                  14    196
# Tennis           19    188
#                  16    185
# Track and Field  20    195
#                  21    188
# Name: Height(cm), dtype: int64

# %% [markdown]
# **EX 3**
# PANDAS exercise

# %%
display(df.groupby(['Sport Type', 'Country']).max(numeric_only=True))
display(df.groupby(['Sport Type', 'Country']).max(numeric_only=True).loc['Basketball','USA'])
display(df.groupby(['Sport Type', 'Country']).max(numeric_only=True).xs(level='Sport Type', key='Soccer'))
display(df[df['Sport Type'].isin(['Soccer', 'Tennis'])].groupby(['Sport Type']).max())
display(df.groupby(['Sport Type', 'Country']).max().swaplevel().sort_index(level=['Sport Type', 'Country']))
display(df.agg({'Wins': ['max', 'mean', 'min', 'std'], 'Height(cm)': ['std', 'mean', 'min', 'max']}).T)
# Out:
#                              Height(cm)  Weight(kg)  Wins
# Sport Type      Country
# Basketball      USA                 216         147     3
# Cycling         Belgium             181          72     5
#                 Netherlands         175          68     4
#                 Slovenia            186          69     3
#                 UK                  183          71     4
# Gymnastics      Romania             155          50     5
#                 USA                 160          52     5
# Soccer          Argentina           170          69     2
#                 Brazil              174          72     3
#                 France              185          80     3
#                 Portugal            187          83     2
#                 USA                 168          62     2
# Swimming        Australia           196          85     4
#                 China               200          90     3
#                 USA                 193          88     5
# ...

# %% [markdown]
# **EX 4**
# PANDAS exercise

# %%
new_rows = pd.DataFrame({
    'Country': ['Canada', 'USA'],
    'Sport Type': ['Hockey', 'Skiing'],
    'Athlete Name': ['Wayne Gretzky', 'Lindsey Vonn'],
    'Height(cm)': [183, 172],
    'Weight(kg)': [84, 68],
    'Wins': [3, 4],
    'Olympic Date': ['01/02/2002', '12/02/2010']
}, index=[36, 37])
df3 = pd.concat([df, new_rows], axis=0)
display(pd.concat([df, new_rows], axis=0))
# Out:
#         Country       Sport Type          Athlete Name  Height(cm)  \
# 0           USA       Basketball        Michael Jordan         198
# 1           USA       Basketball          LeBron James         206
# 2           USA       Basketball           Kobe Bryant         198
# 3           USA       Basketball          Kevin Durant         208
# 4           USA       Basketball      Shaquille O'Neal         216
# 5        Brazil           Soccer                  Pelé         174
# 6        Brazil           Soccer                 Marta         163
# 7      Portugal           Soccer     Cristiano Ronaldo         187
# 8     Argentina           Soccer          Lionel Messi         170
# 9        France           Soccer       Zinedine Zidane         185
# 10          USA           Soccer         Megan Rapinoe         168
# 11          USA         Swimming        Michael Phelps         193
# 12          USA         Swimming         Katie Ledecky         180
# ...

# %% [markdown]
# **EX 5**
# PANDAS exercise

# %%
df2 = pd.read_csv("athletes_smoking.csv")
display(df3)
display(df2)
display(pd.merge(df3, df2, on='Athlete Name', how='inner'))
display(pd.merge(df3, df2, on='Athlete Name', how='outer'))
# Out:
#         Country       Sport Type          Athlete Name  Height(cm)  \
# 0           USA       Basketball        Michael Jordan         198
# 1           USA       Basketball          LeBron James         206
# 2           USA       Basketball           Kobe Bryant         198
# 3           USA       Basketball          Kevin Durant         208
# 4           USA       Basketball      Shaquille O'Neal         216
# 5        Brazil           Soccer                  Pelé         174
# 6        Brazil           Soccer                 Marta         163
# 7      Portugal           Soccer     Cristiano Ronaldo         187
# 8     Argentina           Soccer          Lionel Messi         170
# 9        France           Soccer       Zinedine Zidane         185
# 10          USA           Soccer         Megan Rapinoe         168
# 11          USA         Swimming        Michael Phelps         193
# 12          USA         Swimming         Katie Ledecky         180
# ...
